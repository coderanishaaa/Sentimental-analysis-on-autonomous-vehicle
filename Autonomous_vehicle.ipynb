# %% [markdown]
# About this dataset
# This dataset is your connection to the world of autonomous transport user experience in Luxembourg. It encompasses user feedback from two pilot scenarios conducted within the country: a shared connected vehicle fleet and a bus shuttle designed for commuters. The data collected captures survey results from respondents regarding details such as overall experience, comfort, performance and conveniences associated with their journey. Additionally, the ratings of customer service helpfulness, responsiveness and likelihood of recommending are included.
#
# For those seeking deeper insight into potential patterns or trends beyond user response ratings, this limitless data set holds answers with varied parameters such as individual demographics - language spoken and last name - and survey engagement metrics - duration taken to finish a response cycle as well as total progress made in completing all questions asked.
#
# This data provides unprecedented access to valuable information vital in understanding visitor preferences while also demonstrating how breakthrough innovations hold up against traditional methods of transportation within this context by effectively recording responses in columns detailing sections such Q1 - Q31 that include topics like ease-of-use on the user interface design, safety features offered across both pilots, customer satisfaction ratings for reliability speed or navigation plus many more!
#
# Learn more about consumer sentiments towards autonomous transport today by unlocking this rich source of insights gathered through field testing: dive deep into deeper levels unknown with PAsCAL_WP6_Pilot4 Shared Connected Transport Bus Shuttle & Fleet User Experience Surveys!

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv('Autonomous_Vehicle.csv')
df.head()
# Out:
#                   Progress    Duration (in seconds)                 Finished  \
# 0                 Progress    Duration (in seconds)                 Finished
# 1  {"ImportId":"progress"}  {"ImportId":"duration"}  {"ImportId":"finished"}
# 2                      100                      308                        1
# 3                      100                   170569                        1
# 4                      100                      455                        1
#
#                  ResponseId                 UserLanguage  \
# 0               Response ID                User Language
# 1  {"ImportId":"_recordId"}  {"ImportId":"userLanguage"}
# 2         R_2OZUfpa19AHVfTq                           FR
# 3         R_26ezvyFreDE1PY5                           DE
# 4         R_NXPWmeLeCKRTVpD                        EN-GB
#
#                      Q1                         Q2  \
# 0               Are you    Please tell us your age
# 1  {"ImportId":"QID10"}  {"ImportId":"QID11_TEXT"}
# ...

# %%
# Assuming 'What country do you currently live in?' is the column name
df.rename(columns={'What country do you currently live in?': 'Country'}, inplace=True)
df.rename(columns={'Which city do you currently live in?': 'City'}, inplace=True)

# %%
sns.histplot(data=df, x='Progress', bins=10, kde=True)
plt.title('Distribution of Progress')
plt.xlabel('Progress')
plt.ylabel('Frequency')
plt.show()

sns.histplot(data=df, x='Duration (in seconds)', bins=10, kde=True)
plt.title('Distribution of Duration')
plt.xlabel('Duration (in seconds)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# User Language Distribution

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='UserLanguage')
plt.title('User Language Distribution')
plt.xlabel('User Language')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Response Distribution for Specific Questions:

# %%
# Assuming you want to visualize responses for question Q1
plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Q1')
plt.title('Response Distribution for Question Q1')
plt.xlabel('Response')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Top Topics from Open-ended Responses:

# %%
from wordcloud import WordCloud

# Convert the column to strings and handle NaN values
topics = df['27_9_TEXT - Topics'].astype(str).fillna('')

# Generate the WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(topics))

# Plot the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Topics from Q27_9_TEXT')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='UserLanguage', y='Progress')
plt.title('Progress by User Language')
plt.xlabel('User Language')
plt.ylabel('Progress')
plt.show()

# %% [markdown]
# Progress vs user language

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='UserLanguage', y='Progress')
plt.title('Progress by User Language')
plt.xlabel('User Language')
plt.ylabel('Progress')
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='UserLanguage', y='Duration (in seconds)')
plt.title('Duration by User Language')
plt.xlabel('User Language')
plt.ylabel('Duration (in seconds)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df=pd.read_csv('Autonomous_Vehicle.csv')

# Scatter plot of Progress vs. Duration, colored by UserLanguage
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Progress', y='Duration (in seconds)', hue='UserLanguage', palette='Set1')
plt.title('User Engagement: Progress vs. Duration')
plt.xlabel('Progress')
plt.ylabel('Duration (in seconds)')
plt.legend(title='User Language')
plt.grid(True)
plt.show()
